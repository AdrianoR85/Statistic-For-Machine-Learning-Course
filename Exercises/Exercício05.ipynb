# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Estatística para Ciência de Dados e Machine Learning/Bases de dados/census.csv"

# %%
dataset = pd.read_csv(path)

# %%
dataset.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %%
sns.displot(dataset['age'], kde=True)
plt.show()

# %%
sns.displot(dataset['final-weight'], kde=True)
plt.show()

# %%
sns.displot(dataset['education-num'], kde=False)
plt.show()

# %%
sns.displot(dataset['capital-gain'], kde=False)
plt.show()

# %%
sns.displot(dataset['capital-loos'], kde=False)
plt.show()

# %%
sns.displot(dataset['hour-per-week'], kde=True)
plt.show()

# %%
sns.countplot(x=dataset['marital-status'])
plt.show()

# %%
sns.countplot(x=dataset['sex'])
plt.show()

# %%
sns.countplot(x=dataset['income'])
plt.show()
